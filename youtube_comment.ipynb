# %%
from selenium import webdriver
import time
from openpyxl import Workbook
import pandas as pd
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from konlpy.tag import Okt

okt = Okt()

# %%
wb = Workbook(write_only=True)
ws = wb.create_sheet("sheet1",1)


# 유튜브 URL 가져오는 코뜨
driver = webdriver.Chrome("C:/tool/chromedriver.exe")
driver.get("https://www.youtube.com/watch?v=HbHXi0s1gjc")
driver.implicitly_wait(3)

time.sleep(1.5)

driver.execute_script("window.scrollTo(0, 800)")
time.sleep(3)

# %%
# 떘끌 폐이찌 끝까지 가져오기 
last_height = driver.execute_script("return document.documentElement.scrollHeight")

while True:
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(1.5)

    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(1.5)

# %%
# 팝업 닫기
try:
    driver.find_element_by_css_selector("#dismiss-button > a").click()
except:
    pass

# %%
# 대댓글 노출
#buttons = driver.find_elements_by_css_selector("#more-replies > a")

#time.sleep(1.5)

#for button in buttons:
#    button.send_keys(Keys.ENTER)
#    time.sleep(1.5)
#   button.click()

# %%
# 댓글 가져오기
html_source = driver.page_source
soup = BeautifulSoup(html_source, 'html.parser')

id_list = soup.select("div#header-author > h3 > #author-text > span")
comment_list = soup.select("yt-formatted-string#content-text")

id_final = []
comment_final = []

for i in range(len(comment_list)):
    temp_id = id_list[i].text
    temp_id = temp_id.replace('\n', '')
    temp_id = temp_id.replace('\t', '')
    temp_id = temp_id.replace('    ', '')
    id_final.append(temp_id)

    temp_comment = comment_list[i].text
    temp_comment = temp_comment.replace('\n', '')
    temp_comment = temp_comment.replace('\t', '')
    temp_comment = temp_comment.replace('    ', '')
    comment_final.append(temp_comment)

# %%
# 리스트 데이터 정형화
keyword_list = []

for i in range(len(comment_list)):
    
    print(okt.nouns(comment_final[i]))
# Out:
# ['노래', '칵스']
# ['합주', '진심', '남자', '것']
# ['저', '상황', '합주', '팀원']
# ['치아', '아픔', '오른손', '아픔', '완화', '그', '도대체']
# ['뭐', '드럼', '공연', '때', '스틱', '손', '연주', '전혀', '밀림', '장면', '대박', '프로', '셔']
# ['왜', '대체', '얼마나']
# ['포기', '라이드', '데', '대박']
# ['진짜', '보닼', '부숴질', '그다지']
# ['아아', '그', '바로', '드럼', '조로']
# ['이', '영상', '보고', '칵스', '입덕', '습', '노래', '존']
# ['내', '바로', '스틱', '류', '롤로', '노아', '조로']
# ['진짜', '최고']
# ['광기', '그', '자체']
# ['그대', '열정', '박수', '닼']
# ['세상', '진짜', '극한', '직업', '정신', '리', '스펙']
# ['흥', '순', '겨', '부러']
# ['하이', '햇', '손', '때', '입', '문', '스틱', '낼때', '완전']
# ['열정']
# ['오', '처음', '번', '이상', '보', '프로', '패셔널해', '개', '매력']
# ['입', '문', '스틱', '칠', '때']
# ['하이', '햇', '때', '스틱', '이', '때']
# ['발', '드럼']
# ['존경', '합주', '때', '세상', '텐션']
# ['그냥', '라이드', '열정', '장난']
# ['드럼', '치면', '일이', '절대']
# ['진짜', '꼭', '한번', '저', '열정', '광기', '연주', '진짜', '색시']
# ['손', '매직', '완드', '손', '냄비', '뚜껑', '이', '마법사']
# ['아마추어', '드러머', '로써', '영상']
# ['칵스', '걸', '와중', '디스코', '리듬', '다행', '요']
# ['존나', '선생님']
# ['지금', '학원', '연습실', '드럼', '연습', '움', '저', '한참', '듯']
# ['그', '대체', '때것', '드럼']
# ['창문', '둠칫둠칫하', '기타리스트', '어깨', '흥이', '더']
# ['진짜']
# []
# ['첫', '보고', '입', '스틱', '두번째', '다시', '편', '그림자', '정신', '스틱', '또', '세번', '다시', '입', '문', '스틱', '보고', '음악', '네', '또', '댓글', '또', '다섯', '댓글', '답니', '프로', '정신', '파이팅']
# ['라이드', '그냥']
# ['저', '진짜', '광기']
# ['팩트', '나', '하이', '햇', '부숴질']
# ['피지', '컬', '지리']
# ['순간', '위화', '감', '뭐', '앜']
# ['좀', '진짜']
# ['것', '프로', '정신']
# []
# ['팔', '쥐', '서커스', '묘기', '연주', '필살기', '하이', '헷', '연주']
# ['완', '벽']
# ['거', '풀', '영상']
# ['그거', '입', '행복']
# ['광기', '닼', '멋졐']
# ['존경', '입', '때', '장인정신']
# []
# ['쓰레쉬', '주법', '개', '쩐다']
# ['아하', '하나']
# ['부기', '드럼', '소환', '매렵다']
# ['진짜', '졸라', '머', '싯다']
# ['하이젯', '막대기', '생각', '대비', '입', '물', '군', '생각', '함', '손보', '아아', '거림']
# ['진짜', '프로']
# ['이', '노래', '개띵곡']
# []
# ['전우치', '유해진', '피리', '물']
# ['그냥', '라이드', '치']
# ['기타', '개']
# ['이']
# ['리', '스펙']
# ['손', '속도', '때', '손']
# ['한참']
# ['그냥', '심벌']
# ['위기', '대처', '능력']
# ['이광수', '드럼']
# ['한국', '스티브', '무어']
# []
# ['개멋']
# ['예전', '연주회', '당일', '오신', '교수', '분', '계셧는데', '전공', '타악기', '드럼', '뚱가뚱', '가치', '다가', '스틱', '손', '곡', '스틱', '간지']
# []
# ['와우', '짱', '므찜므찜']
# ['진짜', '간만']
# []
# ['개멋', '있닼']
# ['입', '표정']
# ['도구', '탓', '일류']
# ['열정', '느껸진다']
# ['신']
# ['라이드', '굳이']
# ['개웃곀']
# ['오', '방법']
# []
# ['하이', '햇']
# ['세상']
# ['하이', '햇', '라이드', '그냥']
# []
# ['어후', '머싯다']
# ['간지']
# ['굿']
# ['이형', '대야', '버클리']
# ['표정', '프로야']
# ['대박']
# ['나', '썸넬', '보고', '뭐', '원피스', '조로', '도류', '드럼', '뭐', '줄', '닼']
# ['하이', '햇', '대신', '심벌', '하나', '뮤트']
# ['손', '하나', '비', '발', '배', '바', '와중', '입도', '일']
# []
# ['징', '거']
# []
# ['팔', '근육', '주인']
# []
# []
# ['스틱', '뭘혀', '하이헷', '살이', '낰']
# []
# ['밴드', '마스', '타가', '그', '조폭', '건가']
# ['간지']
# ['이', '템포', '핸드', '감당', '자체', '말']
# ['손']
# ['오', '방법']
# ['방법']
# []
# ['몇번']
# ['이건']
# ['중간', '이빨', '개']
# []
# ['이', '그', '드럼', '채류', '뭐', '겁']
# ['스틱', '왜', '물', '아닠', '처음', '땅']
# ['칵스']
# ['형', '햇']
# ['이', '드럼']
# ['이빨']
# ['저걸', '보고', '우리', '도류']
# ['뭐', '알고리즘', '뭐']
# ['일', '항상', '드럼']
# ['햇']
# ['이건', '예상']
# ['손', '건가', '칠', '별로']
# ['라이드', '심벌']
# ['개', '머시']
# ['드럼', '채', '날라갔엌', '이']
# ['하이헷', '데', '계속']
# ['스틱', '잘못', '치면', '손가락']
# ['뭔가']
# ['와우']
# []
# []
# ['고정']
# []
# []
# ['이빨']
# ['그니', '어스', '코']
# []
# ['노래', '용', '곡', '이름', '뭐']
# ['드럼']
# []
# []
# []
# ['이', '무슨', '곡']
# []
# []
# ['덜덜', '덜']
# ['이분', '은', '왜', '재갈', '벌']
# ['여기', '노래', '제목', '분']
# []
# ['이제', '좀']
# ['합주', '중', '노동', '것']
# ['도류']
# []
# ['저건', '연주가', '고문', '수준']
# ['코']
# ['노래']
# ['도류']
# []
# ['노래', '제목', '제발']
# []
# ['내', '하이', '햇']
# ['자네', '볼', '생각']
# ['노래', '제목', '뭐']
# ['노래', '국악']
# []
# ['무슨', '노랜가']
# ['당신', '드럼', '정점']
# ['저']
# []
# []
# ['산들', '줄', '알']
# []
# ['처음']
# ['노래', '제목', '좀']
# ['코']
# ['손', '치면']
# ['노래', '제목', '뭔가']
# ['이', '영상', '다시']
# ['모르모트']
# ['노래', '제목', '뭘']
# ['유세윤', '줄']
# ['왘']
# []
# ['삼도', '륜줄', '그냥', '지랄']
# []
# ['노래', '제목', '알', '수']
# ['손', '듯']
# ['오', '방법']
# ['얼굴', '진짜']
# ['저기', '이빨']
# ['장난']
# ['건가']
# ['장인', '도구', '탓', '장인', '이건', '좀']
# ['너', '차원', '아이', '화이팅']
# ['인철']
# ['일도']
# ['아앀', '닼']
# ['햌']
# ['거', '노래', '뭡']
# []
# []
# []
# []
# []
# []
# []
# ['어케했노']
# ['미미', '누임']
# []
# []
# []

# %%
# 액셀에 저장
pd_data = {"아이디" : id_final , "댓글 내용" : comment_final}
youtube_pd = pd.DataFrame(pd_data)

youtube_pd.to_excel('youtube_comment.xlsx')
