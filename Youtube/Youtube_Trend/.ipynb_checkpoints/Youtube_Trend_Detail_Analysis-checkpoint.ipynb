# %% [markdown]
# # 유튜브 트렌드 심층 분석

# %% [markdown]
# ## 라이브러리 선언

# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib.request
from selenium.webdriver import Chrome
import re
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt
import os

# %% [markdown]
# ## Chrome drive path 지정

# %%
path = "C:/tool/chromedriver.exe"
delay = 3
browser = Chrome(path)
browser.implicitly_wait(delay)

# %% [markdown]
# ## 유튜브 접속

# %%
start_url = "https://www.youtube.com/feed/trending"
browser.get(start_url)
# browser.maximize_window()

# %% [markdown]
# ## 데이터 담을 리스트 선언

# %%
import pandas as pd

# 리스트 형식 : [ 제목, 채널, 조회수, 시간,  부제목, 링크 ]

# %%
grid = browser.find_element_by_id("grid-container")
videos = grid.find_elements_by_css_selector(".ytd-expanded-shelf-contents-renderer")

trends =[]
for v in videos:
    # 제목 저장
    title = v.find_element_by_css_selector("#video-title").text
    
    # 디테일 정보 크롤링
    details = v.find_element_by_css_selector(".ytd-video-meta-block").text
    details = details.splitlines()
    
    
    # 채널명 저장
    channel = details[0]
    
    # 조회수 저장
    str_match = [s for s in details[1:] if "조회수 " in s]
    views = str_match[0].split(" ")[1]
    
    # 시간 저장
    str_match = [s for s in details[1:] if "전" in s]
    date = str_match[0]
    
    # 부제목 저장
    sub_title = v.find_element_by_css_selector("#description-text").text
    
    #링크 저장
    link = v.find_element_by_css_selector("#video-title").get_attribute("href")
    
    video=[title,channel,views,date,sub_title,link]
    trends.append(video)

# %%
trends = pd.DataFrame(trends,columns=['제목','채널','조회수','시간','부제목','링크'])
trends
# Out:
#                                                    제목  \
# 0   [양팀반응] 손흥민의 개막전 슈퍼골에 놀라는 토트넘 팬들 + 더 놀라는 맨시티 팬들...
# 1   (후토크)'케인 없어도' 손흥민 맨시티 개막전 결승골 토트넘 놀라운 1-0승. 극찬...
# 2          英 BBC "케인 몸값이 2400억원? 손흥민은 2600억원!" (맨시티전)
# 3                              호랑지빠귀 새끼를 삼키려던 누룩뱀의 최후
# 4   과르디올라 패배 인정, "우리는 손흥민처럼 골을 넣지 못했다" (맨시티전 인터뷰+해...
# 5   메시 환영축포?! 득점력 자랑한 PSG 공격진 [🇫🇷리그1 HL 2R PSG vs ...
# 6         손흥민 원더골 보고 케인을 자극하는 현지팬들, 그리고 누누 감독이 남긴 한마디
# 7                               헐리우드 파파라치 돼보기 【아메리카2】
# 8   사이다) 팔로워로 사람 차별하다 전따된 공주병 말기의 최후(사연,06) | [루대숲...
# 9   [ENG] K-어린이들은 달고나 아니고 수제캔디🍭 지옥에서 온 라이언🦁 | Maki...
# 10                                      이집트 점심한끼 200원
# 11  [sub] 🧳스페셜1 | 딸기게임 연습만 세번, 유언비어와 프로참견이 난무하는 현장...
# 12  (예고몰카 3탄)미리 예고장으로 예고를 하고 예고한대로 조져버리는 몰카ㅋㅋㅋㅋㅋㅋㅋ...
# 13       [도장TV 17회] 연우&하영 집에서 어떻게 지내냐구요?? 이러고 놀아요 ㅋㅋㅋ
# 14  불면증인 줄 알았던 강아지 백억이.. 역대급 반전.. 소오름 ㅣThought Dog...
# 15        24시간동안 배달 시켜먹기 VS 수제로 해먹기!! 정말 배달이 더 맛있을까?!
# 16  [아형✪하이라이트] 펜싱으로 지구 대통합💕 선수촌에 빼앗긴 YB 김준호x오상욱에 치...
# 17                    블랙핑크와 촬영 전 날 질투심 없는(?) 여자친구의 반응
# 18  깻잎은 이렇게 요리하면 최고의 맛입니다👍 100장 순삭, 초간단 ! 주기적으로 생각...
# 19  양배추를 이렇게 만들었더니 고기처럼 맛있어요! 순식간에 양배추 한 통이 사라져요 C...
# 20                        야생에서 200시간동안 실제 크기 콜로세움 만들기
# 21                PSG 신입생 환영회, 주인공은 바로 '리오넬 메시' [리그1]
# 22                                           불편한 사람;;
# 23                    1년반만에 만난 국제커플 | 유네린 보바 2021 NEW
# 24                                        말 잘 듣게 하는 법
# 25  [sub] 🧳스페셜2 | 거친 생각과 불안한 눈빛과 근데 이제 인물퀴즈를 곁들인 재...
# 26  【클린버전】 임영웅 - 붉은 입술 💙사랑의 콜센타 66화💙 TV CHOSUN 210...
# 27                             오징어 게임 | 티저 예고편 | 넷플릭스
# 28  Son's stunner claims opening day DELIGHT again...
# 29  [나 혼자 산다] 코트에선 황제여도 집에서는 장꾸 막내딸ㅋㅋ 배구만 1등인 줄 알았...
# 30                다 넣고 40만원 저렴해 진 갤럭시 Z 폴드3 둘러보기 [4K]
# 31  5주년 축하해요 시즈니👋🏻💚ㅣBeyond LIVE - NCT 127 ONLINE F...
# 32   [4K 세로직캠] 임영웅 - 붉은 입술 💙사랑의 콜센타 66화💙무편집 초고화질 세로직캠
# 33  [분데스리가] 도르트문트 VS 프랑크푸르트 - H/LㅣBundesliga 2021-...
# 34      TXT (투모로우바이투게더) 'LO$ER=LO♡ER' Official Teaser
# 35  처음 공개하는 남자친구와 100일 데이트 브이로그 👫🏻💕 케이크도 만들고 깜짝 이벤...
# 36  오사카 근교 핫플🎡 아와지섬에서의 1박2일 vlog | 짱구 테마파크 | 일본 휴게...
# 37           설탕,간장,식초, 절대 넣지마세요 딱 이것만 넣고 1년넘게 보관하는 방법
# 38  DNA Remix - 박재범, YLN Foreign, D.Ark, 365LIT, p...
# 39                        새끼 강아지들을 데려왔을 때 진돗개와 고양이 반응
# 40                         샴푸 전품목 할인 가보자고 [네고왕3] Ep.2
# 41  HIGHLIGHTS | Brentford vs Arsenal (2-0) | Cano...
# 42        싱크대정리 끝장내기 상부장편ㅣ주방정리 수납용품추천 ㅣ28년차 주부의 찐 살림템
# 43                고딩 수포자 카톡방에 숨은 수학쌤 찾기(feat.이투스 고정민)
# 44  (ENG) 한 마디 시키면 두 마디씩 얹는 레드벨벳ㅋㅋㅋㅋㅋ다들 조금씩 은은하게 광...
# 45     우리 엄마가 제일 좋아하는 양파요리 중 하나에요😄 굽자마자 동이나는 아삭아삭 양파전
# 46                          치맥을 처음 먹어본 영국 축구선수들의 반응?!
# 47  [분데스리가] 묀헨글라트바흐 VS 바이에른 뮌헨 - H/L ㅣ Bundesliga ...
# 48    갤럭시Z 플립3 후기, 달라진 점 중심으로~ 커버 디스플레이 삼성페이 가능! [4K]
# 49                          [후토크] 이거 뭐죠? 개막 기념 몰카인가ㅋㅋ
#
#                              채널    조회수      시간  \
# 0                          아이게스   37만회  13시간 전
# 1        박문성 '달수네라이브' dalsulive   30만회  13시간 전
# 2                     서형욱의 뽈리TV   23만회  11시간 전
# 3      KBS동물티비 : 애니멀포유 animal4u   78만회    1일 전
# 4                  한준TV Footics   21만회  12시간 전
# 5   파리 습제르맹 - Paris SBS-Germain   94만회    1일 전
# 6                  김진짜 Real KIM   32만회  10시간 전
# 7              빠니보틀 Pani Bottle   54만회    1일 전
# 8                    루디고 RUDYGO   89만회    2일 전
# 9                   워크맨-Workman  276만회    3일 전
# 10                         보겸TV  142만회  21시간 전
# 11                       채널 십오야  115만회    2일 전
# 12                          보물섬   61만회  23시간 전
# 13                         도장TV  172만회    2일 전
# 14              SBS TV동물농장x애니멀봐   52만회    1일 전
# 15                          파뿌리   78만회    1일 전
# 16             아는형님 Knowingbros   28만회    1일 전
# 17                          깨박이   32만회  21시간 전
# 18                     엄마의 요리백과   31만회    1일 전
# 19           하음쿠킹 Haeum Cooking   43만회    1일 전
# 20                   휘용 Hwiyong   46만회    2일 전
# 21  파리 습제르맹 - Paris SBS-Germain   52만회    1일 전
# 22                          정박수   25만회    1일 전
# 23                     유네린NERIN   38만회  23시간 전
# 24                          끼불이   40만회    2일 전
# 25                       채널 십오야   67만회    2일 전
# 26                미스&미스터트롯 공식계정   39만회    2일 전
# 27       Netflix Korea 넷플릭스 코리아   25만회   9시간 전
# 28            Tottenham Hotspur   75만회  12시간 전
# 29        엠뚜루마뚜루 : MBC 공식 종합 채널  525만회    5일 전
# 30                      UNDERkg   22만회    1일 전
# 31                      NCT 127   38만회  20시간 전
# 32                미스&미스터트롯 공식계정   65만회    3일 전
# 33                   tvN SPORTS   14만회    1일 전
# 34                  HYBE LABELS  207만회  18시간 전
# 35                   유정 YUJEONG   34만회    2일 전
# 36                 토모토모TomoTomo   45만회    1일 전
# 37                         주부나라   41만회    2일 전
# 38                  H1GHR MUSIC   29만회  22시간 전
# 39                       진똑개 풍이   15만회    1일 전
# 40                       달라스튜디오   61만회    2일 전
# 41                      Arsenal  153만회    2일 전
# 42               그림처럼_살림,일상vlog   18만회    2일 전
# 43                        Pixid   90만회    3일 전
# 44                  문명특급 - MMTG  125만회    4일 전
# 45               소소황 Cook & Eat   38만회    2일 전
# 46       영국남자 Korean Englishman  252만회    4일 전
# 47                   tvN SPORTS   28만회    2일 전
# 48                           이퓨    8만회    1일 전
# 49                        이스타TV   37만회    2일 전
#
#                                                   부제목  \
# 0   토트넘의 영웅 손흥민 선수의 개막전 결승골에 대한 현지반응! 과연 어땠을까요? 함께...
# 1   이것이 바로 손! 흥! 민! #손흥민 #토트넘 #탕강가 #모우라 #SonHM7 #T...
# 2   "No Harry Kane? No problem!" "케인이 없다고? 아무 문제 없...
# 24  https://www.youtube.com/watch?v=5Ogij93h3FQ
# 25  https://www.youtube.com/watch?v=HrlFwbz222E
# 26  https://www.youtube.com/watch?v=mO9D8MKWaZo
# 27  https://www.youtube.com/watch?v=lFMobna17QU
# 28  https://www.youtube.com/watch?v=exwCSLlZLfM
# 29  https://www.youtube.com/watch?v=95MGvHIGQP4
# 30  https://www.youtube.com/watch?v=-ScD714niDk
# 31  https://www.youtube.com/watch?v=-pempkM-UOY
# 32  https://www.youtube.com/watch?v=ipGCwhywgnU
# 33  https://www.youtube.com/watch?v=2zxGGMOeeVU
# 34  https://www.youtube.com/watch?v=DWR4OJavJ3o
# 35  https://www.youtube.com/watch?v=0V7QU7nXKfE
# 36  https://www.youtube.com/watch?v=v0GF-6fitko
# 37  https://www.youtube.com/watch?v=9DisNl2rUFQ
# 38  https://www.youtube.com/watch?v=sP6y8aTE5NI
# 39  https://www.youtube.com/watch?v=WYpfty-2u34
# 40  https://www.youtube.com/watch?v=HkMK0l2IJiQ
# 41  https://www.youtube.com/watch?v=RJxHDEC-jAk
# 42  https://www.youtube.com/watch?v=dj1pjAWAhzs
# 43  https://www.youtube.com/watch?v=_MUXpcxktDg
# 44  https://www.youtube.com/watch?v=esm6aAz6eF0
# 45  https://www.youtube.com/watch?v=QOQ9XTEFKuQ
# 46  https://www.youtube.com/watch?v=CKlXdPx26SY
# 47  https://www.youtube.com/watch?v=nKPpUTcebfw
# 48  https://www.youtube.com/watch?v=ND5sQAPdZ9o
# 49  https://www.youtube.com/watch?v=-C26kzFgzQw

# %% [markdown]
# ## 트렌드 심층 분석

# %%
from konlpy.tag import Okt

#한글 댓글에 대한 단어 처리
okt = Okt()

# %% [markdown]
# ### 댓글 크롤링 및 워딩 함수 선언

# %%
def comment_croll(link,driver):
    driver= Chrome(path)
    driver.implicitly_wait(delay)
    driver.get(link)
    driver.implicitly_wait(3)
    time.sleep(1.5)
    driver.execute_script("window.scrollTo(0, 800)")
    time.sleep(3)
    
    
    # 댓글 페이지 추가 노출 코드
    last_height = driver.execute_script("return document.documentElement.scrollHeight")

    while True:
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(1.5)

        new_height = driver.execute_script("return document.documentElement.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    time.sleep(1.5)
    
    
    # 팝업창 제거
    try:
        driver.find_element_by_css_selector("#dismiss-button > a").click()
    except:
        pass
    
    
    # 댓글 크롤링
    html_source = driver.page_source
    soup = BeautifulSoup(html_source, 'html.parser')

    id_list = soup.select("div#header-author > h3 > #author-text > span")
    comment_list = soup.select("yt-formatted-string#content-text")

    id_final = []
    comment_final = []

    for i in range(len(comment_list)):
        temp_id = id_list[i].text
        temp_id = temp_id.replace('\n', '')
        temp_id = temp_id.replace('\t', '')
        temp_id = temp_id.replace('    ', '')
        id_final.append(temp_id)

        temp_comment = comment_list[i].text
        temp_comment = temp_comment.replace('\n', '')
        temp_comment = temp_comment.replace('\t', '')
        temp_comment = temp_comment.replace('    ', '')
        comment_final.append(temp_comment)
        
        
    # 데이터 정제
    keyword_list = []
    word = ""
    for i in range(len(comment_list)):
        words = okt.nouns(comment_final[i])
        word += " ".join(words)
        word += " "
    
    
    
    # 정제된 데이터 빈도수 분석
    wordList = word.split()
    wordLists = []
    wordCount = {} 
    wordCounts = []
     # word -> count 기준 정렬한 dictionary
    for word in wordList:
        # Get 명령어를 통해, Dictionary에 Key가 없으면 0리턴
        wordCount[word] = wordCount.get(word, 0) + 1 

    keys = sorted(wordCount.items(),key=(lambda x:x[1]),reverse=True)

    for word in keys:
        wordLists.append(word[0])  
        wordCounts.append(word[1])
        
    
    pd2_data = {"키워드" : wordLists, "빈도수" : wordCounts}
    youtube_pd2 = pd.DataFrame(pd2_data)
    
    return youtube_pd2

# %% [markdown]
# ### 심층분석 직렬 처리

# %%
youtube_pds = []

for i in range(0,50):
    print(i,"번째 DataFrame 추가 작업 : start")
    browser= Chrome(path)
    browser.implicitly_wait(delay)
    youtube_pds.append(comment_croll(trends['링크'][i],browser))
    print(i,"번째 DataFrame 추가 작업 : done")
# Out:
# 0 번째 DataFrame 추가 작업 : start
# 0 번째 DataFrame 추가 작업 : done
# 1 번째 DataFrame 추가 작업 : start
# 1 번째 DataFrame 추가 작업 : done
# 2 번째 DataFrame 추가 작업 : start
# 2 번째 DataFrame 추가 작업 : done
# 3 번째 DataFrame 추가 작업 : start
# 3 번째 DataFrame 추가 작업 : done
# 4 번째 DataFrame 추가 작업 : start
# 4 번째 DataFrame 추가 작업 : done
# 5 번째 DataFrame 추가 작업 : start
# 5 번째 DataFrame 추가 작업 : done
# 6 번째 DataFrame 추가 작업 : start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-504bd6a17940> in <module>
#       8     browser= Chrome(path)
#       9     browser.implicitly_wait(delay)
# ---> 10     youtube_pds.append(comment_croll(trends['링크'][i],browser))
#      11     print(i,"번째 DataFrame 추가 작업 : done")
#      12
#
# <ipython-input-29-3d54bb3dc14c> in comment_croll(link, driver)
#      13     while True:
#      14         driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
# ---> 15         time.sleep(1.5)
#      16
#      17         new_height = driver.execute_script("return document.documentElement.scrollHeight")
#
# KeyboardInterrupt:

# %% [markdown]
# ## 심층 분석 멀티 프로세싱 처리

# %%
import multiprocessing
import parmap
import numpy as np
import crolling

num_cores = multiprocessing.cpu_count() # 12

data = trends['링크']
splited_data =  np.array_split(data, num_cores)
splited_data = [x.tolist() for x in splited_data]

result = parmap.map(crolling.comment_croll , splited_data, pm_pbar=True, pm_processes=num_cores)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [32:49<00:00, 492.37s/it]

# %% [markdown]
# ### 병렬 처리 결과 병합

# %%
trend = []

for re in result:
    for r in re:
        trend.append(r)
print(trend[0])
# Out:
#      키워드  빈도수
# 0    손흥민   35
# 1     케인   29
# 2     선수   25
# 3     경기   17
# 4      골   14
# ..   ...  ...
# 574  드간거    1
# 575   가지    1
# 576  취취취    1
# 577   가오    1
# 578    랍    1
#
# [579 rows x 2 columns]

# %% [markdown]
# ### 결과 저장

# %%
i=0
writer = pd.ExcelWriter('trend_cnt.xlsx', engine='xlsxwriter')
for t in trend:
    t.to_excel(writer, sheet_name='trend'+str(i))
    i=i+1
writer.save()
