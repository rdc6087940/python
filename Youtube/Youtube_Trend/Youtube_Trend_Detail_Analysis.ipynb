# %% [markdown]
# # 유튜브 트렌드 심층 분석

# %% [markdown]
# ## 라이브러리 선언

# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib.request
from selenium.webdriver import Chrome
import re
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt
import os

# %% [markdown]
# ## Chrome drive path 지정

# %%
path = "C:/tool/chromedriver.exe"
delay = 3
browser = Chrome(path)
browser.implicitly_wait(delay)

# %% [markdown]
# ## 유튜브 접속

# %%
start_url = "https://www.youtube.com/feed/trending"
browser.get(start_url)
# browser.maximize_window()

# %% [markdown]
# ## 데이터 담을 리스트 선언

# %%
import pandas as pd

# 리스트 형식 : [ 제목, 채널, 조회수, 시간,  부제목, 링크 ]

# %%
grid = browser.find_element_by_id("grid-container")
videos = grid.find_elements_by_css_selector(".ytd-expanded-shelf-contents-renderer")

trends =[]
for v in videos:
    # 제목 저장
    title = v.find_element_by_css_selector("#video-title").text
    
    # 디테일 정보 크롤링
    details = v.find_element_by_css_selector(".ytd-video-meta-block").text
    details = details.splitlines()
    
    
    # 채널명 저장
    channel = details[0]
    
    # 조회수 저장
    str_match = [s for s in details[1:] if "조회수 " in s]
    views = str_match[0].split(" ")[1]
    
    # 시간 저장
    str_match = [s for s in details[1:] if "전" in s]
    date = str_match[0]
    
    # 부제목 저장
    sub_title = v.find_element_by_css_selector("#description-text").text
    
    #링크 저장
    link = v.find_element_by_css_selector("#video-title").get_attribute("href")
    
    video=[title,channel,views,date,sub_title,link]
    trends.append(video)

# %%
trends = pd.DataFrame(trends,columns=['제목','채널','조회수','시간','부제목','링크'])
trends
# Out:
#                                                    제목  \
# 0                              [스파이더맨: 노 웨이 홈] 티저 예고편
# 1     [MV] Lee Chan Won(이찬원) _ Convenience store(편의점)
# 2   비록 초기 불량에 걸렸지만... 만족도가 엄청 높은 삼성 갤럭시 Z 플립3 언빡싱&...
# 3   [스우파/1회 풀캠] 라치카 피넛 vs 프라우드먼 립제이 @약자 지목 배틀 Full...
# 4                                     왕좌의 게임 검으로 오이베기
# 5   [스우파/1회 풀캠] 라치카 가비 vs 훅 아이키 @약자 지목 배틀 Full Cam...
# 6   [모아봤습👀] 사상 최초👏 양궁 완전체 6인이 집사부일체에 떴다! 금빛 입담🥇으로 ...
# 7   유러피안 드림을 찾아서 - 아프간 난민 7000Km 지옥의 여정 (KBS_2014....
# 8            real 손톱으로 찍어봄... 갤럭시Z플립3 꼼꼼 장단점 & 하루사용기!
# 9   [슉끌립] 롹의 진수로 또 뒤집어 버린, 윌리K 팀의 'Oops! I Did It ...
# 10  [피크타임] ✨최고 분당 시청률✨ 버스 안에 제덕쿵야가👀!? 올림픽 후 고향에 온 ...
# 11            와이프에게 축구 가르치는 이천수ㅋㅋㅋ (초보자들 무조건 보세요 개꿀팁)
# 12                     약 4,000원어치 고기로 만드는 그럴~듯한 스테이크!
# 13  [놀면 뭐하니?] ⭐놀뭐 맞음⭐ 이 티키타카 그리웠다고요😭 무한도전 패밀리 탄생✨ㅣ...
# 14                                          어차피귀여운유재석
# 15       김종국 놀리려고 런닝맨하는 유재석 #런닝맨 #RunningMan | SBSNOW
# 16                                   [인생84] EP.3 노비84
# 17  [GOING SEVENTEEN] EP.19 TTT에 빠지다 #2 (Dive into...
# 18  (댄스)광야에서 요정미 발산한 송지효와 그걸 바라보는 김종국, 그리고 중매왕 유재석...
# 19                                    백색 감옥 [기묘함 속으로]
# 20               애니메이션: 브롤 동화에 오신 것을 환영합니다! 🏰 [브롤스타즈]
# 21                             MBTI 방과후 분식집 (MBTI 만화)
# 22  벽 조차 없는 집에 살림살이라고는 낡은 냄비 하나. 척박한 숲에서 떠돌이 삶을 사는...
# 23  오늘도 '생수' 마셨는데…알고보니 수질 '부적합'/[신선미의 똑똑한 소비자 리포트]...
# 24         ✨🏰Queendom Restaurant🍽✨ EP. 01ㅣTo. 최강 RV팀💖
# 25             브레이브걸스(Brave Girls) - 술버릇 (운전만해 그후) MV
# 26                     스테인리스웍 길들이고 황금계란볶음밥 만드는 전업주부남편
# 27  World Taekwondo Demonstration Team SURPRISES T...
# 28                                          폴드3로 와플굽기
# 29                                병맛더빙 - 맞추는 사람 IQ140
# 30                                               너도좋아
# 31                      Stray Kids(스트레이 키즈) "소리꾼" M/V
# 32       [골프맨] 딱 두 가지 - 선택과 집중! / 제가 아는 한 이 방법이 최고입니다
# 33        [eng] 밀라논나 '최후의 신발'을 공개합니다. (+신발 오래 신는 관리팁)
# 34             [354 근황_#54] 기욤, 어디 있었기욤? 기욤이 왔기욤! 1탄✨
# 35  코메디언 이수지님이 솥뚜껑 삼겹 김치전골을 드시러 오셨습니다!! (Samgyeops...
# 36  아프간 미군 철수와 탈레반의 장악 총정리! 이보다 썩은 나라는 없다?! | 아프가니...
# 37                      연어 스테이크 맛있게 굽기 (feat. 이원일 셰프)
# 38  '아이폰에서 플립3로 넘어갈까요...??' 고민하는 분들을 위한 아이폰 유저가 본 ...
# 39                                  굿바이 좋좋소【feat.메이킹】
# 40  리얼가족먹방:)칼칼한 갈치조림 만들어서 밥도둑집밥먹방(ft.미역줄기,고구마대무침)ㅣ...
# 41                                                에어컨
# 42  Z플립3 이건 끄셔야 해요..l 안하면 2년동안 손해보는 30가지 초기세팅 필수 설...
# 43                                   [짐승친구들] 여름 VS 겨울
# 44  PC방먹방?! 삼겹살 양념치킨 트러플짜파게티 치즈볼 간장계란밥 떡볶이 소란라면 불고...
# 45                                        19스날이 된 아스날
# 46                                        [신병] 보직변경 6
# 47  한끼에 만칼로리 챌린지 도전 가능?🔥태리로제떡볶이+뿌링클치킨+등심돈까스+치즈돈까스+...
# 48  돌아온 커플 일상 브이로그｜🥞호떡에 도라버린 외국인｜웃긴 썰｜러샤에서 제일 작은 코...
# 49                                    외국 아저씨 따라하기 대참사
#
#                           채널     조회수      시간  \
# 0             sonypictureskr   326만회    2일 전
# 1               1theK (원더케이)    28만회    1일 전
# 2                    ITSub잇섭   156만회    1일 전
# 3              Mnet Official    55만회    1일 전
# 4                 사나고 Sanago    44만회    1일 전
# 5              Mnet Official    55만회    1일 전
# 6          SBS Entertainment    97만회    3일 전
# 7                      세계는지금    56만회    2일 전
# 8                  주연 ZUYONI    39만회    1일 전
# 9                 JTBC Music    52만회    2일 전
# 10             KBS Entertain    39만회    1일 전
# 11                 리춘수 [이천수]    22만회  23시간 전
# 12  백종원의 요리비책 Paik's Cuisine    52만회    2일 전
# 13     엠뚜루마뚜루 : MBC 공식 종합 채널   173만회    3일 전
# 14           런닝맨 - 스브스 공식 채널   144만회    3일 전
# 15       SBS NOW / SBS 공식 채널    65만회    1일 전
# 16                      인생84    47만회    2일 전
# 17                 SEVENTEEN    89만회  22시간 전
# 18                  스브스 예능맛집    33만회    1일 전
# 19                       총몇명    62만회    1일 전
# 20                     브롤스타즈   8.9만회    1일 전
# 21                       에익쿠    26만회    1일 전
# 22   EBSDocumentary (EBS 다큐)    30만회    1일 전
# 23                  한국경제TV뉴스   7.7만회    2일 전
# 24                Red Velvet    40만회  21시간 전
# 25       Brave Entertainment  1271만회    3일 전
# 26                    전업주부남편   6.5만회    1일 전
# 27      America's Got Talent    36만회    1일 전
# 28       발명! 쓰레기걸 Trash girl    65만회    2일 전
# 29                      병맛교수   6.8만회  22시간 전
# 30           런닝맨 - 스브스 공식 채널    72만회    1일 전
# 31         JYP Entertainment  2931만회    3일 전
# 32                [골프맨]조윤성프로    10만회    1일 전
# 33            밀라논나 Milanonna   8.9만회    1일 전
# 34                   354 삼오사    29만회    2일 전
# 35    흥삼이네 Heungsam's Family    79만회    2일 전
# 36               김지윤의 지식Play    43만회    3일 전
# 37                 승우아빠 이상채널    21만회    3일 전
# 38          IT's okay 잇츠 오케이    20만회    3일 전
# 39                       이과장    23만회    1일 전
# 40  꼬꼬PD가족[Kkokko PD Family]    12만회    1일 전
# 41                       장삐쭈   108만회    2일 전
# 42                   에이트 ATE    15만회    3일 전
# 43                        짤툰   141만회    5일 전
# 44               상해기SangHyuk    49만회    3일 전
# 45                       이수날    21만회    2일 전
# 46                       장삐쭈   303만회    1주 전
# 47                  햇도시락HDSR    82만회    4일 전
# 48                  유네린NERIN    42만회    3일 전
# 49             승비니 Seungbini    34만회    3일 전
#
#                                                   부제목  \
# 0   모두가 기다려온 이야기 [스파이더맨: 노 웨이 홈] 티저 예고편 대공개! #스파이더...
# 1   [MV] Lee Chan Won(이찬원) _ Convenience store(편의점...
# 2   도착했습니다! 사전예약으로 구입한 갤럭시 Z 플립3. 현재 엄청난 인기로 사전예약에...
# 3   [스우파/1회 풀캠] 라치카 피넛 vs 프라우드먼 립제이 @약자 지목 배틀 Full...
# 4   🌊국내 최대 콘텐츠 라이브러리 웨이브(wavve)🌊 왕좌의 게임 전 시즌, 체르노빌...
# 5   [스우파/1회 풀캠] 라치카 가비 vs 훅 아이키 @약자 지목 배틀 Full Cam...
# 6   양궁 완전체 6인 X 집사부일체 모아봤습 #집사부일체 #양궁 #모아봤습 ▶ Homp...
# 29  https://www.youtube.com/watch?v=Vr_eL4IBqaA
# 30  https://www.youtube.com/watch?v=PQwrW6aBvxE
# 31  https://www.youtube.com/watch?v=EaswWiwMVs8
# 32  https://www.youtube.com/watch?v=mkBEsOReXrs
# 33  https://www.youtube.com/watch?v=fxSQMVeP8hM
# 34  https://www.youtube.com/watch?v=f_y-Rt7Mh4k
# 35  https://www.youtube.com/watch?v=-px6W3xhtnY
# 36  https://www.youtube.com/watch?v=mK4xZ_dd3g4
# 37  https://www.youtube.com/watch?v=xERlnqgEW_U
# 38  https://www.youtube.com/watch?v=Sp55qE3zuWU
# 39  https://www.youtube.com/watch?v=tP42rZgakgQ
# 40  https://www.youtube.com/watch?v=C-29kDDlBy0
# 41  https://www.youtube.com/watch?v=wV273EAl2hM
# 42  https://www.youtube.com/watch?v=V7I5TFrPN5E
# 43  https://www.youtube.com/watch?v=ZCBpLyfRQWc
# 44  https://www.youtube.com/watch?v=v4hDvtPzGQA
# 45  https://www.youtube.com/watch?v=3WnoKjKK9GE
# 46  https://www.youtube.com/watch?v=2o8IOpxrHXo
# 47  https://www.youtube.com/watch?v=A_-1sK23Z6Q
# 48  https://www.youtube.com/watch?v=MGNXF74BZDs
# 49  https://www.youtube.com/watch?v=0TqB30Ynfmg

# %% [markdown]
# ## 트렌드 심층 분석

# %%
from konlpy.tag import Okt

#한글 댓글에 대한 단어 처리
okt = Okt()

# %% [markdown]
# ### 댓글 크롤링 및 워딩 함수 선언

# %%
def comment_croll(link,driver):
    driver= Chrome(path)
    driver.implicitly_wait(delay)
    driver.get(link)
    driver.implicitly_wait(3)
    time.sleep(1.5)
    driver.execute_script("window.scrollTo(0, 800)")
    time.sleep(3)
    
    
    # 댓글 페이지 추가 노출 코드
    last_height = driver.execute_script("return document.documentElement.scrollHeight")

    while True:
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(1.5)

        new_height = driver.execute_script("return document.documentElement.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    time.sleep(1.5)
    
    
    # 팝업창 제거
    try:
        driver.find_element_by_css_selector("#dismiss-button > a").click()
    except:
        pass
    
    
    # 댓글 크롤링
    html_source = driver.page_source
    soup = BeautifulSoup(html_source, 'html.parser')

    id_list = soup.select("div#header-author > h3 > #author-text > span")
    comment_list = soup.select("yt-formatted-string#content-text")

    id_final = []
    comment_final = []

    for i in range(len(comment_list)):
        temp_id = id_list[i].text
        temp_id = temp_id.replace('\n', '')
        temp_id = temp_id.replace('\t', '')
        temp_id = temp_id.replace('    ', '')
        id_final.append(temp_id)

        temp_comment = comment_list[i].text
        temp_comment = temp_comment.replace('\n', '')
        temp_comment = temp_comment.replace('\t', '')
        temp_comment = temp_comment.replace('    ', '')
        comment_final.append(temp_comment)
        
        
    # 데이터 정제
    keyword_list = []
    word = ""
    for i in range(len(comment_list)):
        words = okt.nouns(comment_final[i])
        word += " ".join(words)
        word += " "
    
    
    
    # 정제된 데이터 빈도수 분석
    wordList = word.split()
    wordLists = []
    wordCount = {} 
    wordCounts = []
     # word -> count 기준 정렬한 dictionary
    for word in wordList:
        # Get 명령어를 통해, Dictionary에 Key가 없으면 0리턴
        wordCount[word] = wordCount.get(word, 0) + 1 

    keys = sorted(wordCount.items(),key=(lambda x:x[1]),reverse=True)

    for word in keys:
        wordLists.append(word[0])  
        wordCounts.append(word[1])
        
    
    pd2_data = {"키워드" : wordLists, "빈도수" : wordCounts}
    youtube_pd2 = pd.DataFrame(pd2_data)
    
    return youtube_pd2

# %% [markdown]
# ### 심층분석 직렬 처리

# %%
youtube_pds = []

for i in range(0,50):
    print(i,"번째 DataFrame 추가 작업 : start")
    browser= Chrome(path)
    browser.implicitly_wait(delay)
    youtube_pds.append(comment_croll(trends['링크'][i],browser))
    print(i,"번째 DataFrame 추가 작업 : done")
# Out:
# 0 번째 DataFrame 추가 작업 : start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-10944aa24a7b> in <module>
#       5     browser= Chrome(path)
#       6     browser.implicitly_wait(delay)
# ----> 7     youtube_pds.append(comment_croll(trends['링크'][i],browser))
#       8     print(i,"번째 DataFrame 추가 작업 : done")
#       9
#
# <ipython-input-8-2b9a47f0f640> in comment_croll(link, driver)
#      16         time.sleep(1.5)
#      17
# ---> 18         new_height = driver.execute_script("return document.documentElement.scrollHeight")
#      19         if new_height == last_height:
#      20             break
#
# ~\anaconda3\envs\tensor\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# ~\anaconda3\envs\tensor\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\anaconda3\envs\tensor\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\anaconda3\envs\tensor\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\envs\tensor\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\envs\tensor\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\envs\tensor\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\envs\tensor\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## 심층 분석 멀티 프로세싱 처리

# %%
import multiprocessing
import parmap
import numpy as np
import crolling

num_cores = multiprocessing.cpu_count() # 12

data = trends['링크']


splited_data =  np.array_split(data, num_cores)
splited_data = [x.tolist() for x in splited_data]

result = parmap.map(crolling.comment_croll , splited_data, pm_pbar=True, pm_processes=num_cores)
# Out:
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ### 병렬 처리 결과 병합

# %%
trend = []

for re in result:
    for r in re:
        trend.append(r)
print(trend[0])
# Out:
#      키워드  빈도수
# 0    손흥민   35
# 1     케인   29
# 2     선수   25
# 3     경기   17
# 4      골   14
# ..   ...  ...
# 574  드간거    1
# 575   가지    1
# 576  취취취    1
# 577   가오    1
# 578    랍    1
#
# [579 rows x 2 columns]

# %% [markdown]
# ### 결과 저장

# %%
i=0
writer = pd.ExcelWriter('trend_cnt.xlsx', engine='xlsxwriter')
for t in trend:
    t.to_excel(writer, sheet_name='trend'+str(i))
    i=i+1
writer.save()

# %% [markdown]
# ## 전체 결과 트렌드 분석

# %%
wordCount = {} 
for t in trend:
    for word in t:
        wordCount[word['키워드']] = wordCount.get(word['키워드'], 0) + int(word['빈도수'])
pd.Data
