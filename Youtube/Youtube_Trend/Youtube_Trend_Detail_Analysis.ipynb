# %% [markdown]
# # 유튜브 트렌드 심층 분석

# %% [markdown]
# ## 라이브러리 선언

# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib.request
from selenium.webdriver import Chrome
import re
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt
import os

# %% [markdown]
# ## Chrome drive path 지정

# %%
path = "C:/tool/chromedriver.exe"
delay = 3
browser = Chrome(path)
browser.implicitly_wait(delay)

# %% [markdown]
# ## 유튜브 접속

# %%
start_url = "https://www.youtube.com/feed/trending"
browser.get(start_url)
# browser.maximize_window()

# %% [markdown]
# ## 데이터 담을 리스트 선언

# %%
import pandas as pd

# 리스트 형식 : [ 제목, 채널, 조회수, 시간,  부제목, 링크 ]

# %%
grid = browser.find_element_by_id("grid-container")
videos = grid.find_elements_by_css_selector(".ytd-expanded-shelf-contents-renderer")

trends =[]
for v in videos:
    # 제목 저장
    title = v.find_element_by_css_selector("#video-title").text
    
    # 디테일 정보 크롤링
    details = v.find_element_by_css_selector(".ytd-video-meta-block").text
    details = details.splitlines()
    
    
    # 채널명 저장
    channel = details[0]
    
    # 조회수 저장
    str_match = [s for s in details[1:] if "조회수 " in s]
    views = str_match[0].split(" ")[1]
    
    # 시간 저장
    str_match = [s for s in details[1:] if "전" in s]
    date = str_match[0]
    
    # 부제목 저장
    sub_title = v.find_element_by_css_selector("#description-text").text
    
    #링크 저장
    link = v.find_element_by_css_selector("#video-title").get_attribute("href")
    
    video=[title,channel,views,date,sub_title,link]
    trends.append(video)

# %%
trends = pd.DataFrame(trends,columns=['제목','채널','조회수','시간','부제목','링크'])
trends
# Out:
#                                                    제목  \
# 0                       Red Velvet 레드벨벳 'Queendom' MV
# 1     [골장면 분석] 손흥민의 결승골로 아케보다 멘디가 욕먹는 이유 (토트넘 vs 맨시티)
# 2                    ‘원더골’ 손흥민, 토트넘 선수들은 왜 갑자기 잘해졌을까?
# 3             담뱃불 붙이려다 '펑'…지하주차장 660여 대 피해 / JTBC 뉴스룸
# 4   [양팀반응] 손흥민의 개막전 슈퍼골에 놀라는 토트넘 팬들 + 더 놀라는 맨시티 팬들...
# 5   (후토크)'케인 없어도' 손흥민 맨시티 개막전 결승골 토트넘 놀라운 1-0승. 극찬...
# 6                 아쉬우면 어때 이렇게 예쁜데🤩갤럭시 Z 플립3 둘러보기 [4K]
# 7                                            Queendom
# 8   英 BBC, 손흥민의 가치는 2600억원! "케인 없다고? 아무 문제 없어!" (맨...
# 9         손흥민 원더골 보고 케인을 자극하는 현지팬들, 그리고 누누 감독이 남긴 한마디
# 10                              헐리우드 파파라치 돼보기 【아메리카2】
# 11                             호랑지빠귀 새끼를 삼키려던 누룩뱀의 최후
# 12  메시 환영축포?! 득점력 자랑한 PSG 공격진 [🇫🇷리그1 HL 2R PSG vs ...
# 13                                 집 "안" 나간 햄지 랜선집들이!
# 14                                      이집트 점심한끼 200원
# 15  사이다) 팔로워로 사람 차별하다 전따된 공주병 말기의 최후(사연,06) | [루대숲...
# 16  과르디올라 패배 인정, "우리는 손흥민처럼 골을 넣지 못했다" (맨시티전 인터뷰+해...
# 17                                        말 잘 듣게 하는 법
# 18  [sub] 🧳스페셜1 | 딸기게임 연습만 세번, 유언비어와 프로참견이 난무하는 현장...
# 19  [ENG] K-어린이들은 달고나 아니고 수제캔디🍭 지옥에서 온 라이언🦁 | Maki...
# 20    [Dance] 라이언 & 춘식 Ep.6 RedVelvet 레드벨벳 ‘Queendom’
# 21  [FULL끌립] ＂다리에 장애가..＂ 자신의 한계를 극복💪🏻한 도심 속 스파이더맨 ...
# 22                                  옥수수 한 알을 괴롭힌자의 최후
# 23          아이폰만 썼는데 Z플립3 사도 될까요? | 아이폰 유저가 느끼는 장단점은?
# 24                             오징어 게임 | 티저 예고편 | 넷플릭스
# 25  [분데스리가] 마인츠 VS 라이프치히 - H/LㅣBundesliga 2021-202...
# 26  [실화Pick] 거제 외상 부자, 민폐 아빠의 실체 #실화탐사대 #실화On MBC2...
# 27                    블랙핑크와 촬영 전 날 질투심 없는(?) 여자친구의 반응
# 28       [도장TV 17회] 연우&하영 집에서 어떻게 지내냐구요?? 이러고 놀아요 ㅋㅋㅋ
# 29                        일반인 3대 770kg?!! 실제로 만났습니다..
# 30                                    해바라기 소시지 이게 될까?
# 31  불면증인 줄 알았던 강아지 백억이.. 역대급 반전.. 소오름 ㅣThought Dog...
# 32  Son's stunner claims opening day DELIGHT again...
# 33  [sub] 🧳스페셜2 | 거친 생각과 불안한 눈빛과 근데 이제 인물퀴즈를 곁들인 재...
# 34  깻잎은 이렇게 요리하면 최고의 맛입니다👍 100장 순삭, 초간단 ! 주기적으로 생각...
# 35  [아형✪하이라이트] 펜싱으로 지구 대통합💕 선수촌에 빼앗긴 YB 김준호x오상욱에 치...
# 36                    1년반만에 만난 국제커플 | 유네린 보바 2021 NEW
# 37  양배추를 이렇게 만들었더니 고기처럼 맛있어요! 순식간에 양배추 한 통이 사라져요 C...
# 38  SUB)살기주의😡! 갑자기 수갑 채우고! 하루종일 커플챌린지 해봤더니 여친 반응ㄷㄷ...
# 39  (예고몰카 3탄)미리 예고장으로 예고를 하고 예고한대로 조져버리는 몰카ㅋㅋㅋㅋㅋㅋㅋ...
# 40                        야생에서 200시간동안 실제 크기 콜로세움 만들기
# 41                           [베이킹] 체크쿠키 Check Cookies
# 42                                           불편한 사람;;
# 43        24시간동안 배달 시켜먹기 VS 수제로 해먹기!! 정말 배달이 더 맛있을까?!
# 44                PSG 신입생 환영회, 주인공은 바로 '리오넬 메시' [리그1]
# 45  네글자 퀴즈 대.참.사. 너무 해맑아서 더 웃긴 더보이즈🤣 당신의 현웃을 책임집니다...
# 46  【클린버전】 임영웅 - 붉은 입술 💙사랑의 콜센타 66화💙 TV CHOSUN 210...
# 47      TXT (투모로우바이투게더) 'LO$ER=LO♡ER' Official Teaser
# 48                다 넣고 40만원 저렴해 진 갤럭시 Z 폴드3 둘러보기 [4K]
# 49  오사카 근교 핫플🎡 아와지섬에서의 1박2일 vlog | 짱구 테마파크 | 일본 휴게...
#
#                              채널     조회수      시간  \
# 0                        SMTOWN  1855만회    1일 전
# 1                          아이게스    53만회    1일 전
# 2                  김진짜 Real KIM    63만회    1일 전
# 3                     JTBC News   187만회    1일 전
# 4                          아이게스    51만회    1일 전
# 5        박문성 '달수네라이브' dalsulive    40만회    1일 전
# 6                       UNDERkg    33만회  23시간 전
# 7                    Red Velvet    39만회    1일 전
# 8                     서형욱의 뽈리TV    27만회    1일 전
# 9                  김진짜 Real KIM    44만회    1일 전
# 10             빠니보틀 Pani Bottle    67만회    2일 전
# 11     KBS동물티비 : 애니멀포유 animal4u   100만회    2일 전
# 12  파리 습제르맹 - Paris SBS-Germain   105만회    2일 전
# 13        집나간햄지 Wandering Hamzy    40만회  22시간 전
# 14                         보겸TV   165만회    2일 전
# 15                   루디고 RUDYGO   104만회    3일 전
# 16                 한준TV Footics    25만회    1일 전
# 17                          끼불이    88만회    3일 전
# 18                       채널 십오야   143만회    3일 전
# 19                  워크맨-Workman   309만회    4일 전
# 20         카카오프렌즈 KAKAO FRIENDS    15만회  10시간 전
# 21           JTBC Entertainment    54만회    1일 전
# 22      조선남자 대길이 Chef in Joseon    12만회    1일 전
# 23                    가전주부 GJJB    17만회  20시간 전
# 24       Netflix Korea 넷플릭스 코리아    46만회    1일 전
# 25                   tvN SPORTS    44만회    1일 전
# 26                        실화 On    22만회   8시간 전
# 27                          깨박이    43만회    2일 전
# 28                         도장TV   206만회    4일 전
# 29                         지기TV    39만회    1일 전
# 30      조선남자 대길이 Chef in Joseon    68만회    3일 전
# 31              SBS TV동물농장x애니멀봐    73만회    2일 전
# 32            Tottenham Hotspur   131만회    1일 전
# 33                       채널 십오야    81만회    3일 전
# 34                     엄마의 요리백과    43만회    2일 전
# 35             아는형님 Knowingbros    32만회    2일 전
# 36                     유네린NERIN    51만회    2일 전
# 37           하음쿠킹 Haeum Cooking    63만회    3일 전
# 38             엔조이커플enjoycouple    29만회    1일 전
# 39                          보물섬    74만회    2일 전
# 40                   휘용 Hwiyong    62만회    3일 전
# 41                           꾸킹   9.9만회  22시간 전
# 42                          정박수    36만회    2일 전
# 43                          파뿌리    99만회    2일 전
# 44  파리 습제르맹 - Paris SBS-Germain    58만회    2일 전
# 45            오락실 팡 Arcade Pang    12만회    1일 전
# 46                미스&미스터트롯 공식계정    52만회    4일 전
# 47                  HYBE LABELS   353만회    1일 전
# 48                      UNDERkg    28만회    2일 전
# 49                 토모토모TomoTomo    52만회    2일 전
#
#                                                   부제목  \
# 0   Red Velvet's 6th Mini Album "Queendom" is out!...
# 1   정말 대단했던 손흥민의 리그 개막전 맨시티 상대 결승골! 어떤 과정이었는지 같이 즐...
# 2   [왓챠]에서 '김진짜'를 검색하시면 '확장판' 영상들을 만나 보실 수 있습니다. P...
# 3   불에 타거나 그을린 차들이 빼곡합니다. 지난주 충남 천안의 한 아파트 지하주차장에서...
# 4   토트넘의 영웅 손흥민 선수의 개막전 결승골에 대한 현지반응! 과연 어땠을까요? 함께...
# 5   이것이 바로 손! 흥! 민! #손흥민 #토트넘 #탕강가 #모우라 #SonHM7 #T...
# 6   - 자세한 사진은 https://bit.ly/3sy1hBv - 가격은 낮아졌는데 외...
# 7   Provided to YouTube by SM Entertainment Queend...
# 8   "No Harry Kane? No problem!" "케인이 없다고? 아무 문제 없...
# 9   [왓챠]에서 '김진짜'를 검색하시면 '확장판' 영상들을 만나 보실 수 있습니다. 손...
# 10  딱 걸렸을 때 오싹오싹 ---------------------------------...
# 11  2012.02.22 kbs 환경스페셜 '숲사냥꾼 어미로 산다는 것' 방송 #호랑지빠...
# 12                             #음바페 #이카르디 #드락슬러 #사라비아
# 13                                 #방콕Vlog #햄지 #Hamzy
# 14  ▶ 보겸의 일상/보이로그(VLOG) : https://url.kr/zn1GOK ▶ ...
# 15  💜루대숲 출연 신청 메일 💜 (연기 영상과 연락처, 경력 꼭 첨부 부탁드립니다) r...
# 16  2021/2022 프리미어리그 1라운드 리뷰 토트넘 홋스퍼 vs 맨체스터 시티 경기...
# 17         #유머 #유머영상 #유머동영상 #웃긴동영상 #웃긴영상 #말잘듣게하는법 #뽀뽀
# 18  #출장십오야 #스페셜 #유료광고포함 부르면, 달려 갑니다! 세계최초(?) 예능배달서...
# 19  JOB것들아~~~♥ 인력소장이다,,,,~~~ 나때는 말여,, 수제 사탕이라고 하면,...
# 20  #RedVelvet #queendom #kpop 라띠라두빠빠디라🎵 🎵 Ryan & ...
# 21  [FULL끌립] ＂다리에 장애가..＂ 자신의 한계를 극복💪🏻한 도심 속 스파이더맨 ...
# 22                                   #shorts #팝콘 #옥수수
# 23  💜 오늘은 갤럭시투고 얼리버드로 빌려온 #Z플립3 초단기간 사용해본 소감을 담은 영...
# 24  넷플릭스 《오징어 게임》 "이건 게임일 뿐입니다" 참가자 456명, 총 상금 456...
# 25  ⚽ Bundesliga 2021-2022 ⚽ 마인츠 VS 라이프치히 - H/L --...
# 26  MBC [실화탐사대]는 토요일 밤8시50분 방송됩니다!! 더 많은 영상이 보고 싶으...
# 27  깨박이 풀영상 ☞ https://www.youtube.com/channel/UCEg...
# 28  이 영상은 유료캠페인입니다.(농식품부, 한국과수농협,농정원) #국산복숭아많이먹기캠페...
# 29  구독,좋아요,댓글은 영상제작에 큰 힘이 됩니다! ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ...
# 30                                 #shorts #해바라기 #소시지
# 31  잠 한 숨 안자고 밤새 거실을 돌아다녔던 행동 수시로 몸을 덜덜 떨던 행동 이 모든...
# 32  Check out the highlights from Tottenham Hotspu...
# 33  #출장십오야 #스페셜 #유료광고포함 부르면, 달려 갑니다! 세계최초(?) 예능배달서...
# 34  #깻잎전 #깻잎 #깻잎요리 안녕하세요 ~^^ 오늘은 5분 만에 만들어 500점 받는...
# 35  [아형✪하이라이트] 펜싱으로 지구 대통합💕 선수촌에 빼앗긴 YB 김준호x오상욱에 치...
# 36  2017년 상해에서 만나 2개월만에 한국-중국 롱디를 시작 2018년 26번의 비행...
# 37  양배추를 이렇게 만들었더니 고기처럼 맛있어서 놀랐어요 요즘 무농약 양배추가 많이 보...
# 38  #엔조이커플 #수갑챌린지 #우리결합했어요 8년이나 봤지만 수갑챌린지 덕에 진귀한 풍...
# 39  · – – 　· – 　– – 　· · · · 　· · · – 　– – · 　– 　–...
# 40  #야생 #건축 #마인크래프트 #콜로세움 3주일이나 걸렸습니다 다음 영상부터는 조금 ...
# 41  강렬하다 꾸몽 : https://www.youtube.com/channel/UCH2...
# 42                                     #shorts #이름부르기
# 43  ※ 노랭이 PD : 저 더 늘었나요? ※ 강호이 : 몸무게는 늘었지 ※ 진렬이 : ...
# 44  #메시 #리오넬메시 #라모스 #하키미 #돈나룸마 #바이날둠 #베이날둠 #PSG #파...
# 45  ✨ 웃느라 목 아픈 더보이즈 탐라 ✨ 03:07 이걸 어떻게 그려ㅋㅋㅋㅋㅋ 03:3...
# 46  오직 【미스&미스터트롯】 공식계정에서만 볼 수 있는 자막없는 클린버전 #미스터트롯 ...
# 47  TXT (투모로우바이투게더) 'LO$ER=LO♡ER' Official Teaser ...
# 48  - 자세한 사진은 https://bit.ly/3k1KkeS - 방수, S펜, 심지어...
# 49  * 이번 영상은 #에스쁘아 의 유료광고를 포함합니다 * 💄에스쁘아 틴트 구매 링크 ...
#
#                                              링크
# 0   https://www.youtube.com/watch?v=c9RzZpV460k
# 1   https://www.youtube.com/watch?v=2khHTWFzoec
# 2   https://www.youtube.com/watch?v=sJoevuInxFc
# 3   https://www.youtube.com/watch?v=XKigsQ3QErE
# 4   https://www.youtube.com/watch?v=DQg5bTNSlIE
# 5   https://www.youtube.com/watch?v=kwh-aiYfIaE
# 6   https://www.youtube.com/watch?v=mDOzG1x97Xs
# 7   https://www.youtube.com/watch?v=CNOE58t4k_o
# 8   https://www.youtube.com/watch?v=4iiONMdf7G8
# 9   https://www.youtube.com/watch?v=8yNdBXmWhOo
# 10  https://www.youtube.com/watch?v=FOzFmlwxeQE
# 11  https://www.youtube.com/watch?v=hQC_qcHOFnc
# 12  https://www.youtube.com/watch?v=vvIF9vAPeuo
# 13  https://www.youtube.com/watch?v=jO0-VGELS0U
# 14  https://www.youtube.com/watch?v=QCMVsxYcC8M
# 15  https://www.youtube.com/watch?v=NBXaRW2wQ_s
# 16  https://www.youtube.com/watch?v=P4DxLbb8_20
# 17  https://www.youtube.com/watch?v=5Ogij93h3FQ
# 18  https://www.youtube.com/watch?v=IriQIkcJSUc
# 19  https://www.youtube.com/watch?v=u2PRxVZjokU
# 20  https://www.youtube.com/watch?v=vXhsFcX6JTg
# 21  https://www.youtube.com/watch?v=MHyHwYDfYHk
# 22  https://www.youtube.com/watch?v=kHyTWBrP34I
# 23  https://www.youtube.com/watch?v=hwIX9aQmd0I
# 24  https://www.youtube.com/watch?v=lFMobna17QU
# 25  https://www.youtube.com/watch?v=FHlEnm_ab9U
# 26  https://www.youtube.com/watch?v=UDA-kLHGkt0
# 27  https://www.youtube.com/watch?v=eCfWF2lor7U
# 28  https://www.youtube.com/watch?v=Yzb1sq_-1Mg
# 29  https://www.youtube.com/watch?v=61oA-V9GMtk
# 30  https://www.youtube.com/watch?v=txMNMLy4fAg
# 31  https://www.youtube.com/watch?v=_nuZs2hY0GI
# 32  https://www.youtube.com/watch?v=exwCSLlZLfM
# 33  https://www.youtube.com/watch?v=HrlFwbz222E
# 34  https://www.youtube.com/watch?v=FpKnkMuf5VU
# 35  https://www.youtube.com/watch?v=w4B_8r7u0XA
# 36  https://www.youtube.com/watch?v=TchvDwcfpmU
# 37  https://www.youtube.com/watch?v=ORQd1W9n4TA
# 38  https://www.youtube.com/watch?v=lFmhkTe_Fgo
# 39  https://www.youtube.com/watch?v=KNwFN0a8_YM
# 40  https://www.youtube.com/watch?v=rTUHCWbFarE
# 41  https://www.youtube.com/watch?v=G7M_ZoJGqf4
# 42  https://www.youtube.com/watch?v=O07Pcxw1jPY
# 43  https://www.youtube.com/watch?v=2rNEQtSk8M4
# 44  https://www.youtube.com/watch?v=tqRap7mjQWo
# 45  https://www.youtube.com/watch?v=L2h62TjEJx0
# 46  https://www.youtube.com/watch?v=mO9D8MKWaZo
# 47  https://www.youtube.com/watch?v=DWR4OJavJ3o
# 48  https://www.youtube.com/watch?v=-ScD714niDk
# 49  https://www.youtube.com/watch?v=v0GF-6fitko

# %% [markdown]
# ## 트렌드 심층 분석

# %%
from konlpy.tag import Okt

#한글 댓글에 대한 단어 처리
okt = Okt()

# %% [markdown]
# ### 댓글 크롤링 및 워딩 함수 선언

# %%
def comment_croll(link,driver):
    driver= Chrome(path)
    driver.implicitly_wait(delay)
    driver.get(link)
    driver.implicitly_wait(3)
    time.sleep(1.5)
    driver.execute_script("window.scrollTo(0, 800)")
    time.sleep(3)
    
    
    # 댓글 페이지 추가 노출 코드
    last_height = driver.execute_script("return document.documentElement.scrollHeight")

    while True:
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(1.5)

        new_height = driver.execute_script("return document.documentElement.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    time.sleep(1.5)
    
    
    # 팝업창 제거
    try:
        driver.find_element_by_css_selector("#dismiss-button > a").click()
    except:
        pass
    
    
    # 댓글 크롤링
    html_source = driver.page_source
    soup = BeautifulSoup(html_source, 'html.parser')

    id_list = soup.select("div#header-author > h3 > #author-text > span")
    comment_list = soup.select("yt-formatted-string#content-text")

    id_final = []
    comment_final = []

    for i in range(len(comment_list)):
        temp_id = id_list[i].text
        temp_id = temp_id.replace('\n', '')
        temp_id = temp_id.replace('\t', '')
        temp_id = temp_id.replace('    ', '')
        id_final.append(temp_id)

        temp_comment = comment_list[i].text
        temp_comment = temp_comment.replace('\n', '')
        temp_comment = temp_comment.replace('\t', '')
        temp_comment = temp_comment.replace('    ', '')
        comment_final.append(temp_comment)
        
        
    # 데이터 정제
    keyword_list = []
    word = ""
    for i in range(len(comment_list)):
        words = okt.nouns(comment_final[i])
        word += " ".join(words)
        word += " "
    
    
    
    # 정제된 데이터 빈도수 분석
    wordList = word.split()
    wordLists = []
    wordCount = {} 
    wordCounts = []
     # word -> count 기준 정렬한 dictionary
    for word in wordList:
        # Get 명령어를 통해, Dictionary에 Key가 없으면 0리턴
        wordCount[word] = wordCount.get(word, 0) + 1 

    keys = sorted(wordCount.items(),key=(lambda x:x[1]),reverse=True)

    for word in keys:
        wordLists.append(word[0])  
        wordCounts.append(word[1])
        
    
    pd2_data = {"키워드" : wordLists, "빈도수" : wordCounts}
    youtube_pd2 = pd.DataFrame(pd2_data)
    
    return youtube_pd2

# %% [markdown]
# ### 심층분석 직렬 처리

# %%
youtube_pds = []

for i in range(0,50):
    print(i,"번째 DataFrame 추가 작업 : start")
    browser= Chrome(path)
    browser.implicitly_wait(delay)
    youtube_pds.append(comment_croll(trends['링크'][i],browser))
    print(i,"번째 DataFrame 추가 작업 : done")
# Out:
# 0 번째 DataFrame 추가 작업 : start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-10944aa24a7b> in <module>
#       5     browser= Chrome(path)
#       6     browser.implicitly_wait(delay)
# ----> 7     youtube_pds.append(comment_croll(trends['링크'][i],browser))
#       8     print(i,"번째 DataFrame 추가 작업 : done")
#       9
#
# <ipython-input-8-2b9a47f0f640> in comment_croll(link, driver)
#      16         time.sleep(1.5)
#      17
# ---> 18         new_height = driver.execute_script("return document.documentElement.scrollHeight")
#      19         if new_height == last_height:
#      20             break
#
# ~\anaconda3\envs\tensor\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# ~\anaconda3\envs\tensor\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\anaconda3\envs\tensor\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\anaconda3\envs\tensor\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\envs\tensor\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\envs\tensor\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\envs\tensor\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\envs\tensor\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\envs\tensor\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## 심층 분석 멀티 프로세싱 처리

# %%
import multiprocessing
import parmap
import numpy as np
import crolling

num_cores = multiprocessing.cpu_count() # 12

data = trends['링크']
splited_data =  np.array_split(data, num_cores)
splited_data = [x.tolist() for x in splited_data]

result = parmap.map(crolling.comment_croll , splited_data, pm_pbar=True, pm_processes=num_cores)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [32:49<00:00, 492.37s/it]

# %% [markdown]
# ### 병렬 처리 결과 병합

# %%
trend = []

for re in result:
    for r in re:
        trend.append(r)
print(trend[0])
# Out:
#      키워드  빈도수
# 0    손흥민   35
# 1     케인   29
# 2     선수   25
# 3     경기   17
# 4      골   14
# ..   ...  ...
# 574  드간거    1
# 575   가지    1
# 576  취취취    1
# 577   가오    1
# 578    랍    1
#
# [579 rows x 2 columns]

# %% [markdown]
# ### 결과 저장

# %%
i=0
writer = pd.ExcelWriter('trend_cnt.xlsx', engine='xlsxwriter')
for t in trend:
    t.to_excel(writer, sheet_name='trend'+str(i))
    i=i+1
writer.save()

# %% [markdown]
# ## 전체 결과 트렌드 분석

# %%
wordCount = {} 
for t in trend:
    for word in t:
        wordCount[word['키워드']] = wordCount.get(word['키워드'], 0) + int(word['빈도수'])
pd.Data
